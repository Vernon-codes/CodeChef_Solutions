# %% [markdown]
# # Strings

# %%
#add space between 2 string
print("first"+" "+"second")
# Out:
# first second

# %%
#output of the following code
phrase = "Coding, World!"
print(phrase[6])
# Out:
# ,

# %%
#change character of a string 
s='cable' #change the character at index 3 to r
var=s[:3]+'r'+s[4:]
print(var) #variable
# Out:
# cabre

# %%
#string and integer concatenation
s="5"
print(s+5) #output will be error because we cannot concatenate string and integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 #string and integer concatenation
#       2 s="5"
# ----> 3 print(s+5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#reverse and print the string 
v="I love Python"
print(v[::-1]) #it will start from the end and print the string in reverse order
# Out:
# nohtyP evol I

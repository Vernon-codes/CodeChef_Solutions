# %% [markdown]
# # Variables and Data Types

# %%
#Declare a float datatype
a=12.5
print(a)
print(type(a))
# Out:
# 12.5
# <class 'float'>

# %%
#Declare a long datatype
b=200e1000000
print(type(b))
# Out:
# <class 'float'>

# %%
#Divide two numbers
x=20
y=6
print(x//y)
# Out:
# 3

# %%
#Convert the temperature 
temperature=25.5
kelvin=25.5+273
print("Celsius-",temperature)
print("Kelvin-",kelvin)
# Out:
# Celsius- 25.5
# Kelvin- 298.5

# %%
#Area and perimeter of a Square 
side=4.5
print(side*side)
print(4*side)
# Out:
# 20.25
# 18.0
